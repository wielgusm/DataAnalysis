# %%
import numpy as np
import pandas as pd
import sys
sys.path.append('/Users/mwielgus/Works/EHT/eat')
from eat.io import hops, util
from eat.hops import util as hu
import matplotlib.pyplot as plt
import TrianglesA #https://github.com/wielgusm

# %%
alist = hops.read_alist('/Volumes/SanDiskMW/Data2017/alist.v6.5s')
util.add_gmst(alist)

# %%
pol='LL'
for basename in list(set(alist['baseline'])): 
    try:
        TrianglesA.plotBaseline(alist,basename,pol,'snr', 'snrstd')
    except (IndexError,KeyError,ValueError):
        print 'Error for baseline '+basename
        continue

# %%
pol='RR'
for basename in list(set(alist['baseline'])): 
    try:
        TrianglesA.plotBaseline(alist,basename,pol,'snr', 'snrstd')
    except (IndexError,KeyError,ValueError):
        print 'Error for baseline '+basename
        continue
# Out:
# Error for baseline JR
# Error for baseline PR
# Error for baseline LR
# Error for baseline AR
# Error for baseline XR
# Error for baseline ZR
# Error for baseline SR

# %%
pol='LR'
for basename in list(set(alist['baseline'])): 
    try:
        TrianglesA.plotBaseline(alist,basename,pol,'snr', 'snrstd')
    except (IndexError,KeyError,ValueError):
        print 'Error for baseline '+basename
        continue
# Out:
# Error for baseline JR
# Error for baseline PR
# Error for baseline LR
# Error for baseline AR
# Error for baseline XR
# Error for baseline ZR
# Error for baseline SR

# %%
pol='RL'
for basename in list(set(alist['baseline'])): 
    try:
        TrianglesA.plotBaseline(alist,basename,pol,'snr', 'snrstd')
    except (IndexError,KeyError,ValueError):
        print 'Error for baseline '+basename
        continue
